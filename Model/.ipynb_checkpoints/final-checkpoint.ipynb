# %%
import numpy as np 
import pickle
import itertools
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
import pandas as pd

train = pd.read_csv('C:\\users\\hp\\OneDrive\\Desktop\\Intrusion-Detection-System1\\kdd_train.csv', on_bad_lines='skip')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
train['protocol_type']=le.fit_transform(train['protocol_type'].astype("str"))
train['protocol_type'].value_counts()
# Out:
# protocol_type
# 1    579
# 2     81
# 0     43
# Name: count, dtype: int64

# %%
train['labels'].unique()
# Out:
# array(['normal', 'neptune', 'warezclient', 'ipsweep', 'portsweep',
#        'teardrop', 'nmap', 'satan', 'smurf', 'pod', 'back',
#        'guess_passwd'], dtype=object)

# %%
train.loc[train['labels']=='neptune', 'labels'] = 'dos'
train.loc[train['labels']=='teardrop', 'labels'] = 'dos'
train.loc[train['labels']=='smurf', 'labels'] = 'dos'
train.loc[train['labels']=='pod', 'labels'] = 'dos'
train.loc[train['labels']=='back', 'labels'] = 'dos'
train.loc[train['labels']=='land', 'labels'] = 'dos'

train.loc[train['labels']=='warezclient', 'labels'] = 'R2L'
train.loc[train['labels']=='ipsweep', 'labels'] = 'probe'
train.loc[train['labels']=='portsweep', 'labels'] = 'probe'
 
train.loc[train['labels']=='nmap', 'labels'] = 'probe'
train.loc[train['labels']=='satan', 'labels'] = 'probe'
train.loc[train['labels']=='guess_passwd', 'labels'] = 'R2L'
train.loc[train['labels']=='ftp_write', 'labels'] = 'R2L' 
train.loc[train['labels']=='multihop', 'labels'] = 'R2L' 
train.loc[train['labels']=='rootkit', 'labels'] = 'U2R' 
train.loc[train['labels']=='buffer_overflow', 'labels'] = 'U2R' 
train.loc[train['labels']=='imap', 'labels'] = 'R2L' 
train.loc[train['labels']=='loadmodule', 'labels'] = 'U2R' 
train.loc[train['labels']=='phf', 'labels'] = 'R2L' 
train.loc[train['labels']=='spy', 'labels'] = 'R2L' 
train.loc[train['labels']=='perl', 'labels'] = 'U2R'

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
train['protocol_type']=le.fit_transform(train['protocol_type'].astype("str"))
train['protocol_type'].value_counts()
# Out:
# protocol_type
# 1    579
# 2     81
# 0     43
# Name: count, dtype: int64

# %%
#from sklearn.preprocessing import LabelEncoder
#le=LabelEncoder()
#train['service']=le.fit_transform(train['service'].astype("str"))
#train['service'].value_counts()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
train['flag']=le.fit_transform(train['flag'].astype("str"))
train['flag'].value_counts()
# Out:
# flag
# 5    415
# 3    196
# 0     63
# 2     16
# 1     10
# 6      2
# 4      1
# Name: count, dtype: int64

# %%
 x_train= train[['duration','dst_bytes','src_bytes','is_guest_login','is_host_login','diff_srv_rate','srv_diff_host_rate','flag','protocol_type']]

# %%
x_train
# Out:
#      duration  dst_bytes  src_bytes  is_guest_login  is_host_login  \
# 0           0          0        491               0              0
# 1           0          0        146               0              0
# 2           0          0          0               0              0
# 3           0       8153        232               0              0
# 4           0        420        199               0              0
# ..        ...        ...        ...             ...            ...
# 698         0       2698        301               0              0
# 699         0       3295        246               0              0
# 700         0      12471        230               0              0
# 701         0         82         46               0              0
# 702      1985        105        147               0              0
#
#      diff_srv_rate  srv_diff_host_rate  flag  protocol_type
# 0             0.00                0.00     5              1
# ...

# %%
 rain= train[['duration','dst_bytes','src_bytes','is_guest_login','is_host_login','diff_srv_rate','srv_diff_host_rate', 'flag','protocol_type','labels']]

# %%
rain.tail()
# Out:
#      duration  dst_bytes  src_bytes  is_guest_login  is_host_login  \
# 698         0       2698        301               0              0
# 699         0       3295        246               0              0
# 700         0      12471        230               0              0
# 701         0         82         46               0              0
# 702      1985        105        147               0              0
#
#      diff_srv_rate  srv_diff_host_rate  flag  protocol_type  labels
# 698           0.00                0.22     5              1  normal
# 699           0.00                0.33     5              1  normal
# 700           0.00                0.29     5              1  normal
# 701           0.01                0.01     5              2  normal
# 702           0.00                0.00     5              2  normal

# %%
rain
# Out:
#      duration  dst_bytes  src_bytes  is_guest_login  is_host_login  \
# 0           0          0        491               0              0
# 1           0          0        146               0              0
# 2           0          0          0               0              0
# 3           0       8153        232               0              0
# 4           0        420        199               0              0
# ..        ...        ...        ...             ...            ...
# 698         0       2698        301               0              0
# 699         0       3295        246               0              0
# 700         0      12471        230               0              0
# 701         0         82         46               0              0
# 702      1985        105        147               0              0
#
#      diff_srv_rate  srv_diff_host_rate  flag  protocol_type  labels
# 0             0.00                0.00     5              1  normal
# ...

# %%
x_train
# Out:
#      duration  dst_bytes  src_bytes  is_guest_login  is_host_login  \
# 0           0          0        491               0              0
# 1           0          0        146               0              0
# 2           0          0          0               0              0
# 3           0       8153        232               0              0
# 4           0        420        199               0              0
# ..        ...        ...        ...             ...            ...
# 698         0       2698        301               0              0
# 699         0       3295        246               0              0
# 700         0      12471        230               0              0
# 701         0         82         46               0              0
# 702      1985        105        147               0              0
#
#      diff_srv_rate  srv_diff_host_rate  flag  protocol_type
# 0             0.00                0.00     5              1
# ...

# %%
rain[(rain['labels']=='normal')].head(10)
# Out:
#     duration  dst_bytes  src_bytes  is_guest_login  is_host_login  \
# 0          0          0        491               0              0
# 1          0          0        146               0              0
# 3          0       8153        232               0              0
# 4          0        420        199               0              0
# 12         0       2251        287               0              0
# 16         0      13788        300               0              0
# 18         0        616        233               0              0
# 19         0       1178        343               0              0
# 22         0      11905        253               0              0
# 23      5607        105        147               0              0
#
#     diff_srv_rate  srv_diff_host_rate  flag  protocol_type  labels
# 0            0.00                0.00     5              1  normal
# 1            0.15                0.00     5              2  normal
# ...

# %%
y_train=train['labels']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=9)
print(X_train.shape)
print(X_test.shape)
# Out:
# (492, 9)
# (211, 9)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=9)
pca.fit(X_train)
X_train_scaled_pca = pca.transform(X_train)
X_test_scaled_pca = pca.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators=10, random_state=0)
classifier.fit(X_train_scaled_pca, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
classifier.score(X_train_scaled_pca,y_train)
# Out:
# 0.9898373983739838

# %%
from sklearn.metrics import accuracy_score
y_pred = classifier.predict(X_test_scaled_pca )
accuracy_score(y_pred,y_test)
# Out:
# 0.9715639810426541

# %%
import pickle

#pickle.dump(classifier,open('sk.pkl','wb'))
#classifier = pickle.load(open('sk.pkl','rb'))

# %%
pickle.dump(classifier,open('sk.pkl','wb'))
pickle.dump(pca, open('pca.pkl', 'wb'))
